# %%
# Note: After you run this cell, the training and test data will be available in
# the file browser. (Click the folder icon on the left to view it)
#
# If you don't see the data after the cell completes, click the refresh button
# in the file browser (folder icon with circular arrow)

# First, let's download and unzip the data
# !echo "Downloading files..."
# !wget -q https://github.com/byui-cse/cse450-course/raw/master/data/roadsigns/training1.zip
# !wget -q https://github.com/byui-cse/cse450-course/raw/master/data/roadsigns/training2.zip
# !wget -q https://github.com/byui-cse/cse450-course/raw/master/data/roadsigns/test.zip

# !echo "Unzipping files..."
# !unzip -q /content/training1.zip
# !unzip -q /content/training2.zip
# !unzip -q /content/test.zip

# Combine the two traning directories
# !echo "Mergining training data..."
# !mkdir /content/training
# !mv /content/training1/* /content/training
# !mv /content/training2/* /content/training

# Cleanup
# !echo "Cleaning up..."
# !rmdir /content/training1
# !rmdir /content/training2
# !rm training1.zip
# !rm training2.zip
# !rm test.zip

# !echo "Data ready."
# Out:
# Downloading files...
# Unzipping files...
# Mergining training data...
# Cleaning up...
# Data ready.

# %%
# Import libraries
import pandas as pd
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.client import device_lib
from tensorflow.keras import layers
import os

# %%
# Create an image training dataset
from tensorflow.keras.preprocessing import image_dataset_from_directory

# We're using keras' image_dataset_from_directory method to load our image data.
# See (https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image_dataset_from_directory) for details
#
# A couple of things to note:
# 1. We're specifying a number for the seed, so we'll always get the same shuffle and split of our images.
# 2. Class names are inferred automatically from the image subdirectory names.
# 3. We're splitting the training data into 80% training, 20% validation. 

training_dir = '/content/training'
image_size = (100, 100)
training_data = image_dataset_from_directory(training_dir, validation_split=.2, subset='training', seed=512, image_size=image_size)
val_data = image_dataset_from_directory(training_dir, validation_split=0.2, subset='validation', seed=512, image_size=image_size)
# Out:
# Found 39209 files belonging to 43 classes.
# Using 31368 files for training.
# Found 39209 files belonging to 43 classes.
# Using 7841 files for validation.

# %%
import matplotlib.pyplot as plt

# View first 9 images and their class labels
plt.figure(figsize=(10, 10))
for images, labels in training_data.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(training_data.class_names[labels[i]])
    plt.axis("off")

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D

# create the base pre-trained model
base_model = InceptionV3(weights='imagenet', include_top=False)

# add a global spatial average pooling layer
x = base_model.output
x = GlobalAveragePooling2D()(x)
# let's add a fully-connected layer
x = Dense(512, activation='relu')(x)
# and a logistic layer -- let's say we have 200 classes
predictions = Dense(44, activation='softmax')(x)

# this is the model we will train
model = Model(inputs=base_model.input, outputs=predictions)

# first: train only the top layers (which were randomly initialized)
# i.e. freeze all convolutional InceptionV3 layers
for layer in base_model.layers:
    layer.trainable = False

# compile the model (should be done *after* setting layers to non-trainable)
model.compile(optimizer='rmsprop', loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics=['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
epochs = 20
history = model.fit(
    training_data,
    validation_data = val_data,
    epochs=epochs
)
# Out:
# Epoch 1/20
# 981/981 [==============================] - 43s 44ms/step - loss: 8.8258 - accuracy: 0.1290 - val_loss: 3.0922 - val_accuracy: 0.1760
# Epoch 2/20
# 981/981 [==============================] - 42s 42ms/step - loss: 3.2249 - accuracy: 0.1642 - val_loss: 3.5914 - val_accuracy: 0.1687
# Epoch 3/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1377 - accuracy: 0.1760 - val_loss: 3.2388 - val_accuracy: 0.2079
# Epoch 4/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1609 - accuracy: 0.1864 - val_loss: 3.0024 - val_accuracy: 0.1927
# Epoch 5/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1757 - accuracy: 0.1924 - val_loss: 3.0424 - val_accuracy: 0.2023
# Epoch 6/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1341 - accuracy: 0.1910 - val_loss: 3.0829 - val_accuracy: 0.2012
# Epoch 7/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1215 - accuracy: 0.1992 - val_loss: 3.0941 - val_accuracy: 0.2052
# Epoch 8/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1429 - accuracy: 0.1934 - val_loss: 3.0438 - val_accuracy: 0.1886
# Epoch 9/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1004 - accuracy: 0.2014 - val_loss: 3.0832 - val_accuracy: 0.2118
# Epoch 10/20
# 981/981 [==============================] - 42s 42ms/step - loss: 3.1221 - accuracy: 0.2029 - val_loss: 3.1963 - val_accuracy: 0.1958
# Epoch 11/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1307 - accuracy: 0.2023 - val_loss: 3.6498 - val_accuracy: 0.2094
# Epoch 12/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1214 - accuracy: 0.2135 - val_loss: 4.6720 - val_accuracy: 0.1908
# Epoch 13/20
# 981/981 [==============================] - 41s 42ms/step - loss: 3.1167 - accuracy: 0.2105 - val_loss: 3.8152 - val_accuracy: 0.2257
# Epoch 14/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1159 - accuracy: 0.2125 - val_loss: 3.2636 - val_accuracy: 0.2139
# Epoch 15/20
# 981/981 [==============================] - 42s 42ms/step - loss: 3.0998 - accuracy: 0.2130 - val_loss: 3.3068 - val_accuracy: 0.2086
# Epoch 16/20
# 981/981 [==============================] - 41s 42ms/step - loss: 3.0845 - accuracy: 0.2140 - val_loss: 3.5016 - val_accuracy: 0.2306
# Epoch 17/20
# 981/981 [==============================] - 42s 42ms/step - loss: 3.1101 - accuracy: 0.2133 - val_loss: 3.2381 - val_accuracy: 0.2196
# Epoch 18/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1098 - accuracy: 0.2122 - val_loss: 3.1974 - val_accuracy: 0.2081
# Epoch 19/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1479 - accuracy: 0.2096 - val_loss: 3.1438 - val_accuracy: 0.1919
# Epoch 20/20
# 981/981 [==============================] - 42s 43ms/step - loss: 3.1677 - accuracy: 0.2076 - val_loss: 3.3386 - val_accuracy: 0.2135

# %%
model.save('/content/drive/MyDrive/Machine Learning/Module 6/Checkpoints/toplayerstrained.h5')

# %%
# we chose to train the top 2 inception blocks, i.e. we will freeze
# the first 249 layers and unfreeze the rest:
for layer in model.layers[:249]:
   layer.trainable = False
for layer in model.layers[249:]:
   layer.trainable = True

# we need to recompile the model for these modifications to take effect
# we use SGD with a low learning rate
from tensorflow.keras.optimizers import SGD
model.compile(optimizer=SGD(lr=0.0001, momentum=0.9), loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics=['accuracy'])

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
epochs = 60
history = model.fit(
    training_data,
    validation_data = val_data,
    epochs=epochs
)
model.save('/content/drive/MyDrive/Machine Learning/Module 6/Checkpoints/fifthset.h5')
# Out:
# Epoch 1/60
# 981/981 [==============================] - 51s 52ms/step - loss: 3.2485 - accuracy: 0.1953 - val_loss: 2.7655 - val_accuracy: 0.2645
# Epoch 2/60
# 981/981 [==============================] - 49s 50ms/step - loss: 2.7216 - accuracy: 0.2719 - val_loss: 2.5075 - val_accuracy: 0.3232
# Epoch 3/60
# 981/981 [==============================] - 49s 50ms/step - loss: 2.5246 - accuracy: 0.3206 - val_loss: 2.3666 - val_accuracy: 0.3623
# Epoch 4/60
# 981/981 [==============================] - 49s 50ms/step - loss: 2.3734 - accuracy: 0.3641 - val_loss: 2.2408 - val_accuracy: 0.4089
# Epoch 5/60
# 981/981 [==============================] - 48s 49ms/step - loss: 2.2612 - accuracy: 0.3936 - val_loss: 2.1312 - val_accuracy: 0.4253
# Epoch 6/60
# 981/981 [==============================] - 48s 49ms/step - loss: 2.1447 - accuracy: 0.4302 - val_loss: 2.0583 - val_accuracy: 0.4559
# Epoch 7/60
# 981/981 [==============================] - 48s 49ms/step - loss: 2.0639 - accuracy: 0.4476 - val_loss: 1.9884 - val_accuracy: 0.4751
# Epoch 8/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.9236 - accuracy: 0.4786 - val_loss: 1.9184 - val_accuracy: 0.4848
# Epoch 9/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.8158 - accuracy: 0.4997 - val_loss: 1.7446 - val_accuracy: 0.5201
# Epoch 10/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.7128 - accuracy: 0.5173 - val_loss: 1.6038 - val_accuracy: 0.5397
# Epoch 11/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.6109 - accuracy: 0.5402 - val_loss: 1.5871 - val_accuracy: 0.5455
# Epoch 12/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.4997 - accuracy: 0.5645 - val_loss: 1.4966 - val_accuracy: 0.5737
# Epoch 13/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.4290 - accuracy: 0.5833 - val_loss: 1.4246 - val_accuracy: 0.5911
# Epoch 14/60
# 981/981 [==============================] - 48s 48ms/step - loss: 1.3532 - accuracy: 0.6038 - val_loss: 1.3384 - val_accuracy: 0.6096
# Epoch 15/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.2930 - accuracy: 0.6189 - val_loss: 1.3080 - val_accuracy: 0.6261
# Epoch 16/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.2062 - accuracy: 0.6446 - val_loss: 1.2903 - val_accuracy: 0.6196
# Epoch 17/60
# 981/981 [==============================] - 49s 50ms/step - loss: 1.1622 - accuracy: 0.6566 - val_loss: 1.2043 - val_accuracy: 0.6580
# Epoch 18/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.1021 - accuracy: 0.6784 - val_loss: 1.1254 - val_accuracy: 0.6776
# Epoch 19/60
# 981/981 [==============================] - 48s 49ms/step - loss: 1.0562 - accuracy: 0.6927 - val_loss: 1.0839 - val_accuracy: 0.6845
# Epoch 20/60
# 981/981 [==============================] - 48s 48ms/step - loss: 1.0112 - accuracy: 0.7020 - val_loss: 1.0889 - val_accuracy: 0.6901
# Epoch 21/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.9651 - accuracy: 0.7181 - val_loss: 1.0195 - val_accuracy: 0.7056
# Epoch 22/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.9159 - accuracy: 0.7321 - val_loss: 1.0155 - val_accuracy: 0.7108
# Epoch 23/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.8710 - accuracy: 0.7464 - val_loss: 0.9840 - val_accuracy: 0.7147
# Epoch 24/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.8357 - accuracy: 0.7516 - val_loss: 0.9299 - val_accuracy: 0.7349
# Epoch 25/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.7872 - accuracy: 0.7692 - val_loss: 0.9120 - val_accuracy: 0.7415
# Epoch 26/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.7708 - accuracy: 0.7736 - val_loss: 0.8848 - val_accuracy: 0.7526
# Epoch 27/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.7346 - accuracy: 0.7859 - val_loss: 0.8464 - val_accuracy: 0.7634
# Epoch 28/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.6929 - accuracy: 0.7948 - val_loss: 0.8845 - val_accuracy: 0.7551
# Epoch 29/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.6745 - accuracy: 0.8007 - val_loss: 0.8551 - val_accuracy: 0.7583
# Epoch 30/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.6494 - accuracy: 0.8086 - val_loss: 0.7946 - val_accuracy: 0.7778
# Epoch 31/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.6162 - accuracy: 0.8184 - val_loss: 0.7939 - val_accuracy: 0.7795
# Epoch 32/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.6036 - accuracy: 0.8199 - val_loss: 0.7894 - val_accuracy: 0.7792
# Epoch 33/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.5675 - accuracy: 0.8334 - val_loss: 0.7245 - val_accuracy: 0.8000
# Epoch 34/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.5373 - accuracy: 0.8408 - val_loss: 0.7079 - val_accuracy: 0.8088
# Epoch 35/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.5254 - accuracy: 0.8457 - val_loss: 0.7314 - val_accuracy: 0.7967
# Epoch 36/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.5165 - accuracy: 0.8466 - val_loss: 0.7430 - val_accuracy: 0.7959
# Epoch 37/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.4773 - accuracy: 0.8585 - val_loss: 0.6720 - val_accuracy: 0.8125
# Epoch 38/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.4697 - accuracy: 0.8608 - val_loss: 0.6815 - val_accuracy: 0.8143
# Epoch 39/60
# 981/981 [==============================] - 49s 49ms/step - loss: 0.4527 - accuracy: 0.8681 - val_loss: 0.6566 - val_accuracy: 0.8244
# Epoch 40/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.4349 - accuracy: 0.8722 - val_loss: 0.6887 - val_accuracy: 0.8132
# Epoch 41/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.4233 - accuracy: 0.8740 - val_loss: 0.6247 - val_accuracy: 0.8296
# Epoch 42/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.4060 - accuracy: 0.8790 - val_loss: 0.6958 - val_accuracy: 0.8152
# Epoch 43/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.3925 - accuracy: 0.8840 - val_loss: 0.6613 - val_accuracy: 0.8260
# Epoch 44/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.3953 - accuracy: 0.8832 - val_loss: 0.6103 - val_accuracy: 0.8382
# Epoch 45/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.4120 - accuracy: 0.8768 - val_loss: 0.6350 - val_accuracy: 0.8269
# Epoch 46/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.3854 - accuracy: 0.8864 - val_loss: 0.6216 - val_accuracy: 0.8376
# Epoch 47/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.3684 - accuracy: 0.8911 - val_loss: 0.5757 - val_accuracy: 0.8463
# Epoch 48/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.3418 - accuracy: 0.8995 - val_loss: 0.6513 - val_accuracy: 0.8317
# Epoch 49/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.3281 - accuracy: 0.9038 - val_loss: 0.5755 - val_accuracy: 0.8491
# Epoch 50/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.3034 - accuracy: 0.9092 - val_loss: 0.5441 - val_accuracy: 0.8573
# Epoch 51/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.2976 - accuracy: 0.9117 - val_loss: 0.5541 - val_accuracy: 0.8546
# Epoch 52/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.2984 - accuracy: 0.9099 - val_loss: 0.5435 - val_accuracy: 0.8598
# Epoch 53/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.2817 - accuracy: 0.9156 - val_loss: 0.5199 - val_accuracy: 0.8630
# Epoch 54/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.2796 - accuracy: 0.9178 - val_loss: 0.5585 - val_accuracy: 0.8540
# Epoch 55/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.2762 - accuracy: 0.9193 - val_loss: 0.6252 - val_accuracy: 0.8403
# Epoch 56/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.2644 - accuracy: 0.9215 - val_loss: 0.5803 - val_accuracy: 0.8486
# Epoch 57/60
# 981/981 [==============================] - 49s 49ms/step - loss: 0.2646 - accuracy: 0.9202 - val_loss: 0.5804 - val_accuracy: 0.8530
# Epoch 58/60
# 981/981 [==============================] - 49s 50ms/step - loss: 0.2538 - accuracy: 0.9237 - val_loss: 0.5469 - val_accuracy: 0.8624
# Epoch 59/60
# 981/981 [==============================] - 48s 49ms/step - loss: 0.2514 - accuracy: 0.9234 - val_loss: 0.5322 - val_accuracy: 0.8667
# Epoch 60/60
# 981/981 [==============================] - 47s 48ms/step - loss: 0.2566 - accuracy: 0.9239 - val_loss: 0.5083 - val_accuracy: 0.8683

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
