# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import neighbors

# %%
spotify = pd.read_csv('https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/spotify/data.csv')
categories = spotify.columns
categories
selection = ['acousticness', 'danceability', 'duration_ms', 'energy',
       'explicit', 'instrumentalness', 'key', 'liveness', 'loudness',
       'mode', 'popularity', 'speechiness', 'tempo',
       'valence', 'year']
data = spotify[selection]
mode_enum = enumerate(["minor", "major"])
data[data.year>50].describe()
# Out:
#         acousticness   danceability  ...        valence           year
# count  169909.000000  169909.000000  ...  169909.000000  169909.000000
# mean        0.493214       0.538150  ...       0.532095    1977.223231
# std         0.376627       0.175346  ...       0.262408      25.593168
# min         0.000000       0.000000  ...       0.000000    1921.000000
# 25%         0.094500       0.417000  ...       0.322000    1957.000000
# 50%         0.492000       0.548000  ...       0.544000    1978.000000
# 75%         0.888000       0.667000  ...       0.749000    1999.000000
# max         0.996000       0.988000  ...       1.000000    2020.000000
#
# [8 rows x 15 columns]

# %%
data[data.popularity>48].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cea67b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0ce00a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cdb5cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cde9f28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cda81d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cd5c438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cd106a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0ccc38d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0ccc3940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0ccabdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cc6d080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cc1e2e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cbd2550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cb837b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cb37a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0cb6cc88>]],
#       dtype=object)

# %%
filtered=data[(data.popularity>62) & (data.year >= 1950)]
filtered[["loudness", "speechiness", "danceability", "duration_ms", "energy", "valence", "tempo"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c85e2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c3cb1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c36e438>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c3a26a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c354908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c309b70>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c2c24e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c274828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c274898>]],
#       dtype=object)

# %%
filtered=data[(data.popularity<12) & (data.year >= 1950)]
filtered[["loudness", "speechiness", "danceability", "duration_ms", "energy", "valence", "tempo"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c0ab4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c0b6b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c081eb8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c03e278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bfef5f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c021978>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bfd4cf8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bf96080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bf960f0>]],
#       dtype=object)

# %%
filtered=data[(data.year >= 1950)]
filtered[["loudness", "speechiness", "danceability", "duration_ms", "energy", "valence", "tempo"]].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c8fc6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c84b3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0c37a0b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0be49048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0be0dac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bd23550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bcd57b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bc879e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0bc87a58>]],
#       dtype=object)

# %% [markdown]
# loudness - first factor of importance
#     speechiness - second factor
#     dancibility - third factor
# 	tempo - fourth
# 	valence - fifth
# 	energy - sixth
# 	duration - seventh
#
#
# loudness
# speechiness
# dancibility
# tempo
# valence
# energy
# duration

# %%
categories =["loudness",
             "speechiness",
             "danceability",
             "tempo",
             "valence",
             "energy",
             "duration_ms"]
category = categories[0]
X=data["speechiness"]
y=data["popularity"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

n_neighbors=5
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30)
knn = neighbors.KNeighborsRegressor(n_neighbors)
#knn.fit(X_train, y_train)
#predictions = knn.predict(X_test)
#cm = confusion_matrix(y_test, predictions)
#print(cm)

# %%
#Array([1,2,3]).reshape(-1,1)

# %%
#np.array[1,2,3]

# %%
#before 1950, we don't have as much data.
focus_data = data[data.year >=1950]
flop_max_popularity = focus_data.popularity.describe()["25%"]
hit_min_popularity = focus_data.popularity.describe()["75%"]
flops = focus_data[focus_data.popularity <= flop_max_popularity]
hits = focus_data[focus_data.popularity >= hit_min_popularity]
med = focus_data[(focus_data.popularity < hit_min_popularity) & (focus_data.popularity>flop_max_popularity)]
selection=["loudness", "speechiness", "danceability", "duration_ms", "energy", "valence", "tempo"]

# %%
focus_data.describe()
focus_data.hist()
# Out:
#         acousticness   danceability  ...        valence           year
# count  141606.000000  141606.000000  ...  141606.000000  141606.000000
# mean        0.418745       0.544084  ...       0.533218    1984.929586
# std         0.353902       0.174292  ...       0.261642      20.446156
# min         0.000000       0.000000  ...       0.000000    1950.000000
# 25%         0.062100       0.427000  ...       0.324000    1967.000000
# 50%         0.351000       0.553000  ...       0.542000    1985.000000
# 75%         0.768000       0.670000  ...       0.751000    2003.000000
# max         0.996000       0.988000  ...       1.000000    2020.000000
#
# [8 rows x 15 columns]

# %%
focus_data[selection].hist(bins=20, figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a07686198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0762e320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a076595c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0760a940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a075becc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0757d048>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0752c400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0755f748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0755f7b8>]],
#       dtype=object)

# %%
flops[selection].describe()
# Out:
#            loudness   speechiness  ...       valence         tempo
# count  36136.000000  36136.000000  ...  36136.000000  36136.000000
# mean     -13.758603      0.083528  ...      0.516983    113.696850
# std        5.353969      0.145853  ...      0.270207     30.698277
# min      -60.000000      0.000000  ...      0.000000      0.000000
# 25%      -16.757000      0.034800  ...      0.290000     89.924000
# 50%      -12.997000      0.042500  ...      0.529000    111.105500
# 75%       -9.982750      0.060900  ...      0.743000    132.544000
# max        1.812000      0.968000  ...      0.993000    218.443000
#
# [8 rows x 7 columns]

# %%
flops[selection].hist(bins=20, figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a07240eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a072caba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a071fb518>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a071ab898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a071dcc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a07190f98>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a0714c358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a070fe6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a070fe710>]],
#       dtype=object)

# %%
hits[selection].describe()
# Out:
#            loudness   speechiness  ...       valence         tempo
# count  35841.000000  35841.000000  ...  35841.000000  35841.000000
# mean      -8.016895      0.089064  ...      0.511305    120.475913
# std        4.639668      0.096281  ...      0.250576     30.233445
# min      -54.376000      0.000000  ...      0.000000      0.000000
# 25%       -9.576000      0.034500  ...      0.314000     96.477000
# 50%       -6.906000      0.047600  ...      0.509000    119.896000
# 75%       -5.114000      0.094400  ...      0.712000    140.013000
# max        1.342000      0.955000  ...      0.993000    220.099000
#
# [8 rows x 7 columns]

# %%
hits[selection].hist(bins=20, figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06fc8588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06e4c940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06e15b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06dc7e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06d86208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06d38588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a08834908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a07a7ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a07abda90>]],
#       dtype=object)

# %%
med[selection].describe()
# Out:
#            loudness   speechiness  ...       valence         tempo
# count  69629.000000  69629.000000  ...  69629.000000  69629.000000
# mean     -10.334693      0.072378  ...      0.552924    119.952014
# std        4.939540      0.085106  ...      0.261227     30.044508
# min      -60.000000      0.000000  ...      0.000000      0.000000
# 25%      -12.933000      0.033300  ...      0.345000     96.715000
# 50%       -9.587000      0.042600  ...      0.566000    117.364000
# 75%       -6.768000      0.068100  ...      0.773000    138.247000
# max        3.744000      0.964000  ...      1.000000    244.091000
#
# [8 rows x 7 columns]

# %%
med[selection].hist(bins=20, figsize=(10,6))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06a5d5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a069ff898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a069a8b00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a069dcd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06990fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a06951278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f4a069044e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a068ba080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f4a068ba0f0>]],
#       dtype=object)

# %%
hits.loudness.hist()

# %%
flops.loudness.hist()

# %%
med.loudness.hist()

# %%
data
# Out:
#         acousticness  danceability  duration_ms  ...    tempo  valence  year
# 0             0.9950         0.708       158648  ...  118.469   0.7790  1928
# 1             0.9940         0.379       282133  ...   83.972   0.0767  1928
# 2             0.6040         0.749       104300  ...  107.177   0.8800  1928
# 3             0.9950         0.781       180760  ...  108.003   0.7200  1928
# 4             0.9900         0.210       687733  ...   62.149   0.0693  1928
# ...              ...           ...          ...  ...      ...      ...   ...
# 169904        0.1730         0.875       163800  ...  100.012   0.3060  2020
# 169905        0.0167         0.719       167468  ...  128.000   0.2700  2020
# 169906        0.5380         0.514       180700  ...  123.700   0.1530  2020
# 169907        0.0714         0.646       167308  ...  129.916   0.4720  2020
# 169908        0.1090         0.512       214787  ...   80.588   0.3660  2020
#
# [169909 rows x 15 columns]

# %% [markdown]
# [MMC Entertainment is a real company that publishes rap.](https://sound.mmcentertainments.com/). Let's see what's the deal with rap...

# %%
genres_url = "https://raw.githubusercontent.com/byui-cse/cse450-course/master/data/spotify/data_by_genres.csv"
genres = pd.read_csv(genres_url)

# %%
genres
# Out:
#               genres  acousticness  danceability  ...  popularity  key  mode
# 0              432hz      0.494780      0.299333  ...   52.166667    5     1
# 1                 []      0.679245      0.521473  ...   21.682005    7     1
# 2         a cappella      0.621532      0.577017  ...   43.351819   11     1
# 3           abstract      0.359395      0.459500  ...   41.500000    1     1
# 4     abstract beats      0.353347      0.694400  ...   58.600000   10     0
# ...              ...           ...           ...  ...         ...  ...   ...
# 2659            zolo      0.218600      0.560365  ...   33.760410    9     1
# 2660         zouglou      0.124000      0.834000  ...   56.000000    7     0
# 2661            zouk      0.233181      0.752762  ...   42.476190    4     1
# 2662     zouk riddim      0.052700      0.776000  ...   24.000000    4     1
# 2663          zydeco      0.347767      0.596992  ...   29.840152    7     1
#
# [2664 rows x 14 columns]

# %%
focused_genres = genres[["rap" in mystring and "trap" not in mystring for mystring in genres.genres]]

# %%
focused_genres
# Out:
#                        genres  acousticness  ...  key  mode
# 38                alabama rap      0.135907  ...    2     1
# 210           baton rouge rap      0.127731  ...    1     1
# 211                battle rap      0.064944  ...    6     1
# 359                  cali rap      0.145045  ...    1     1
# 454               chicago rap      0.181652  ...    1     1
# 457               chicano rap      0.168765  ...    1     1
# 601                comedy rap      0.159674  ...    7     1
# 637               country rap      0.147160  ...   11     1
# 791                   dfw rap      0.157647  ...    4     1
# 795           dirty south rap      0.095788  ...    1     1
# 796           dirty texas rap      0.135644  ...    1     1
# 804                   dmv rap      0.181717  ...    1     0
# 896                   emo rap      0.280798  ...   11     1
# 960               florida rap      0.202731  ...   11     0
# 1034             gangster rap      0.113323  ...    1     1
# 1067   german underground rap      0.065000  ...    2     1
# 1085               gospel rap      0.196000  ...    8     1
# 1098       grand rapids indie      0.031121  ...   11     1
# 1191              houston rap      0.102803  ...    1     1
# 1228            indie pop rap      0.190712  ...    1     1
# 1331                    j-rap      0.173333  ...    6     1
# 1395                 jazz rap      0.144760  ...    1     1
# 1403          jazz vibraphone      0.771439  ...    5     1
# 1420                    k-rap      0.210122  ...    8     1
# 1512               london rap      0.153336  ...    0     1
# 1572              melodic rap      0.177528  ...    1     1
# 1574                 meme rap      0.258654  ...    1     1
# 1611             military rap      0.248831  ...    9     1
# 1752           new jersey rap      0.147846  ...    7     1
# 1758          new orleans rap      0.112964  ...    6     1
# 1806        norwegian pop rap      0.131000  ...    4     0
# 1834                  nyc rap      0.209244  ...    1     1
# 1881               ottawa rap      0.122172  ...    1     1
# 1915               philly rap      0.128502  ...    1     1
# 1925    pinoy alternative rap      0.507200  ...    5     1
# 1937           pittsburgh rap      0.147507  ...    1     1
# 1969                  pop rap      0.161067  ...    1     1
# 2022                proto-rap      0.368000  ...   11     0
# 2065                      rap      0.150576  ...    1     1
# 2066              rap chileno      0.036990  ...    6     0
# 2067           rap conciencia      0.330665  ...    2     1
# 2068            rap conscient      0.396321  ...    4     1
# 2069            rap cristiano      0.543202  ...    7     1
# 2070           rap dominicano      0.130441  ...    7     1
# 2071              rap espanol      0.560000  ...    4     1
# 2072               rap kreyol      0.118076  ...    7     1
# 2073               rap latina      0.261689  ...    5     1
# 2074                rap metal      0.043737  ...    1     1
# 2075           rap napoletano      0.969750  ...   10     1
# 2076                 rap rock      0.039053  ...    1     1
# 2171            san diego rap      0.186446  ...   11     1
# 2190               scream rap      0.089667  ...    1     1
# 2354      swedish gangsta rap      0.185000  ...    7     0
# 2378  swedish underground rap      0.077100  ...   11     0
# 2445              toronto rap      0.153397  ...    1     0
# 2533          underground rap      0.222051  ...   11     1
# 2618           west coast rap      0.120677  ...    1     1
#
# [57 rows x 14 columns]

# %%
focused_genres[selection].describe()
# Out:
#         loudness  speechiness  danceability  ...     energy    valence       tempo
# count  57.000000    57.000000     57.000000  ...  57.000000  57.000000   57.000000
# mean   -7.425515     0.170631      0.693144  ...   0.648541   0.546529  118.153361
# std     2.249372     0.071814      0.110091  ...   0.121720   0.134382   14.087385
# min   -17.809000     0.034600      0.310000  ...   0.169125   0.123000   70.231000
# 25%    -7.679128     0.133331      0.682339  ...   0.606000   0.486409  109.027380
# 50%    -6.970304     0.177477      0.722333  ...   0.666648   0.549333  118.206990
# 75%    -6.449483     0.224494      0.755669  ...   0.693348   0.614000  126.113815
# max    -4.007000     0.289915      0.893000  ...   0.902000   0.800833  169.988000
#
# [8 rows x 7 columns]
